# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read CSV
dataframe = pd.read_csv("combined_attacks_data.csv")

# %%
dataframe.head()
# Out:
#   case_number     date    year attack_type country     area  \
# 0  2019.08.27  8/27/19  2019.0    Provoked     USA  Florida
# 1  2019.08.21  8/21/19  2019.0  Unprovoked     USA  Florida
# 2  2019.08.20  8/20/19  2019.0  Unprovoked     USA   Hawaii
# 3  2019.08.16  8/16/19  2019.0  Unprovoked     USA  Florida
# 4  2019.08.11  8/11/19  2019.0  Unprovoked     USA   Hawaii
#
#                                           location  activity  \
# 0                 New Smyrna Beach, Volusia County   Surfing
# 1                  Fort Lauderdale, Broward County    Wading
# 2  Napoopoo Park in Kealakekua Bay, The Big Island  Swimming
# 3                 New Smyrna Beach, Volusia County    Wading
# 4                               Makaha Beach, Oahu   Surfing
#
#                  name sex  ...  case_number.2 original_order unnamed:_22  \
# 0        Donald Walsh   M  ...     2019.08.27         6452.0         NaN
# 1  Christian Mariani    M  ...     2019.08.21         6451.0         NaN
# ...

# %%
# Show the columns of the DataFrame
print(dataframe.columns)
# Out:
# Index(['case_number', 'date', 'year', 'attack_type', 'country', 'area',
#        'location', 'activity', 'name', 'sex', 'age', 'injury', 'fatal_(y/n)',
#        'time', 'species', 'investigator_or_source', 'pdf', 'href_formula',
#        'href', 'case_number.1', 'case_number.2', 'original_order',
#        'unnamed:_22', 'unnamed:_23', 'details', 'bear_species', 'latitude',
#        'longitude', 'month', 'day'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
dataframe = pd.read_csv("combined_attacks_data.csv")

# Display the first few rows of the dataframe
print(dataframe.head())

# Get a summary of the dataframe
print(dataframe.info())

# Get basic statistics of numeric columns
print(dataframe.describe())

# Get basic statistics of non-numeric columns
print(dataframe.describe(include=[object]))

# Check for missing values
missing_values = dataframe.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Drop columns with a high number of missing values
dataframe = dataframe.drop(columns=['unnamed:_22', 'unnamed:_23'])

# Fill missing values with appropriate values or drop rows with missing values
dataframe['age'].fillna('Unknown', inplace=True)
dataframe.dropna(subset=['latitude', 'longitude'], inplace=True)

# Convert data types if necessary
dataframe['year'] = pd.to_numeric(dataframe['year'], errors='coerce')
dataframe['date'] = pd.to_datetime(dataframe['date'], errors='coerce')

# Plot the distribution of attacks by year
plt.figure(figsize=(12, 6))
sns.histplot(dataframe['year'].dropna(), bins=30, kde=True)
plt.title('Distribution of Attacks by Year')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()

# Plot the count of attacks by country
plt.figure(figsize=(12, 6))
sns.countplot(y=dataframe['country'], order=dataframe['country'].value_counts().index, palette='viridis')
plt.title('Count of Attacks by Country')
plt.xlabel('Number of Attacks')
plt.ylabel('Country')
plt.show()

# Plot the distribution of attacks by age
plt.figure(figsize=(12, 6))
sns.histplot(dataframe['age'].dropna(), bins=30, kde=True)
plt.title('Distribution of Attacks by Age')
plt.xlabel('Age')
plt.ylabel('Number of Attacks')
plt.show()

# Plot the count of fatal attacks
plt.figure(figsize=(6, 6))
sns.countplot(x=dataframe['fatal_(y/n)'], palette='coolwarm')
plt.title('Count of Fatal Attacks')
plt.xlabel('Fatal (Y/N)')
plt.ylabel('Number of Attacks')
plt.show()

# Plot a heatmap of missing values
plt.figure(figsize=(12, 6))
sns.heatmap(dataframe.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values')
plt.show()
# Out:
#   case_number     date    year attack_type country     area  \
# 0  2019.08.27  8/27/19  2019.0    Provoked     USA  Florida
# 1  2019.08.21  8/21/19  2019.0  Unprovoked     USA  Florida
# 2  2019.08.20  8/20/19  2019.0  Unprovoked     USA   Hawaii
# 3  2019.08.16  8/16/19  2019.0  Unprovoked     USA  Florida
# 4  2019.08.11  8/11/19  2019.0  Unprovoked     USA   Hawaii
#
#                                           location  activity  \
# 0                 New Smyrna Beach, Volusia County   Surfing
# 1                  Fort Lauderdale, Broward County    Wading
# 2  Napoopoo Park in Kealakekua Bay, The Big Island  Swimming
# 3                 New Smyrna Beach, Volusia County    Wading
# 4                               Makaha Beach, Oahu   Surfing
#
#                  name sex  ...  case_number.2 original_order unnamed:_22  \
# 0        Donald Walsh   M  ...     2019.08.27         6452.0         NaN
# 1  Christian Mariani    M  ...     2019.08.21         6451.0         NaN
# ...

# %%
import pandas as pd
import folium
from IPython.display import display
                                                                           # Bear attacks
# Load your data
# Replace 'your_data_file.csv' with the path to your actual data file
df = pd.read_csv('combined_attacks_data.csv')

# Filter the data to include only rows with valid latitude and longitude
df = df.dropna(subset=['latitude', 'longitude'])

# Create a base map centered around the mean latitude and longitude
m = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=2)

# Add points to the map
for idx, row in df.iterrows():
    # Determine the type of species
    species = row['species'] if pd.notna(row['species']) else row['bear_species']
    # Set a different color for each species
    color = 'blue' if species.lower() == 'shark' else 'red'
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f'Species: {species}',
        icon=folium.Icon(color=color)
    ).add_to(m)

# Display the map in Jupyter Notebook
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
# Read the data into a Pandas DataFrame
shark_data_raw_df = pd.read_excel("GSAF5-1.xls")
shark_data_raw_df.head()
# Out:
#   Case Number         Date    Year        Type Country     Area  \
# 0  2019.08.27  27-Aug-2019  2019.0    Provoked     USA  Florida
# 1  2019.08.21  21-Aug-2019  2019.0  Unprovoked     USA  Florida
# 2  2019.08.20  20-Aug-2019  2019.0  Unprovoked     USA   Hawaii
# 3  2019.08.16  16-Aug-2019  2019.0  Unprovoked     USA  Florida
# 4  2019.08.11  11-Aug-2019  2019.0  Unprovoked     USA   Hawaii
#
#                                           Location  Activity  \
# 0                 New Smyrna Beach, Volusia County   Surfing
# 1                  Fort Lauderdale, Broward County    Wading
# 2  Napoopoo Park in Kealakekua Bay, The Big Island  Swimming
# 3                 New Smyrna Beach, Volusia County    Wading
# 4                               Makaha Beach, Oahu   Surfing
#
#                  Name Sex   ...          Species   \
# 0        Donald Walsh    M  ...        6.5' shark
# 1  Christian Mariani     M  ...               NaN
# 2              female    F  ...               NaN
# ...

# %%
import pandas as pd

# Step 1: Read the data into a Pandas DataFrame
shark_data_raw_df = pd.read_excel("GSAF5-1.xls")

# Step 2: Display the first few rows of the DataFrame
print("First 5 rows:")
print(shark_data_raw_df.head())

# Step 3: Display the last few rows of the DataFrame
print("\nLast 5 rows:")
print(shark_data_raw_df.tail())

# Step 4: Access a single row by index
print("\n11th row (index 10):")
print(shark_data_raw_df.iloc[10])

# Step 5: Access multiple rows by index
print("\nRows from index 5 to 9:")
print(shark_data_raw_df.iloc[5:10])

# Step 6: Access rows based on a condition
# Example condition: Display rows where a specific column's value is greater than a threshold
# Replace 'column_name' with an actual column name from your DataFrame and 'some_value' with an actual value
# filtered_rows = shark_data_raw_df[shark_data_raw_df['column_name'] > some_value]
# print("\nFiltered rows based on condition:")
# print(filtered_rows)
# Out:
# First 5 rows:
#   Case Number         Date    Year        Type Country     Area  \
# 0  2019.08.27  27-Aug-2019  2019.0    Provoked     USA  Florida
# 1  2019.08.21  21-Aug-2019  2019.0  Unprovoked     USA  Florida
# 2  2019.08.20  20-Aug-2019  2019.0  Unprovoked     USA   Hawaii
# 3  2019.08.16  16-Aug-2019  2019.0  Unprovoked     USA  Florida
# 4  2019.08.11  11-Aug-2019  2019.0  Unprovoked     USA   Hawaii
#
#                                           Location  Activity  \
# 0                 New Smyrna Beach, Volusia County   Surfing
# 1                  Fort Lauderdale, Broward County    Wading
# 2  Napoopoo Park in Kealakekua Bay, The Big Island  Swimming
# 3                 New Smyrna Beach, Volusia County    Wading
# 4                               Makaha Beach, Oahu   Surfing
#
#                  Name Sex   ...          Species   \
# 0        Donald Walsh    M  ...        6.5' shark
# 1  Christian Mariani     M  ...               NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data into a Pandas DataFrame
shark_data_raw_df = pd.read_excel("GSAF5-1.xls")

# Drop columns that are not necessary
shark_data_cleaned_df = shark_data_raw_df.drop(columns=['Unnamed: 22', 'Unnamed: 23'])

# Drop rows with missing 'Case Number'
shark_data_cleaned_df = shark_data_cleaned_df.dropna(subset=['Case Number'])

# Drop rows with missing 'Location' or 'Species'
shark_data_cleaned_df = shark_data_cleaned_df.dropna(subset=['Location', 'Species'])

# Aggregate the data by Location and Species
location_species_counts = shark_data_cleaned_df.groupby(['Location', 'Species']).size().reset_index(name='Counts')

# Display the aggregated data
print(location_species_counts.head())

# Create a bar plot using Seaborn
plt.figure(figsize=(14, 8))
sns.barplot(data=location_species_counts, x='Location', y='Counts', hue='Species')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Shark Attack Incidents by Location and Species')
plt.xlabel('Location')
plt.ylabel('Number of Incidents')
plt.legend(title='Species', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lx/4rt8gjpx3tndjbrqc3j96cr80000gp/T/ipykernel_30509/2989518017.py in ?()
#      11 # Drop rows with missing 'Case Number'
#      12 shark_data_cleaned_df = shark_data_cleaned_df.dropna(subset=['Case Number'])
#      13
#      14 # Drop rows with missing 'Location' or 'Species'
# ---> 15 shark_data_cleaned_df = shark_data_cleaned_df.dropna(subset=['Location', 'Species'])
#      16
#      17 # Aggregate the data by Location and Species
#      18 location_species_counts = shark_data_cleaned_df.groupby(['Location', 'Species']).size().reset_index(name='Counts')
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
# ...
